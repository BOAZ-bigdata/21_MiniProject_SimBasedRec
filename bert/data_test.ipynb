# %%
from datasets import load_dataset

# %%
data_st = load_dataset("lbox/lbox_open", "statute_classification")

# %%
data_st_plus = load_dataset("lbox/lbox_open", "statute_classification_plus")

# %%
data_st = data_st.shuffle()
data_st_plus = data_st_plus.shuffle()

# %%
print(data_st["train"]["statutes"][:3])
print(data_st["train"]["facts"][:3])
# Out:
# [['형법 제231조', '형법 제234조'], ['형법 제347조 제1항'], ['형법 제283조 제1항', '형법 제284조']]
# ['1. 피고인은 2017. 8. 8.경 서울 서초구 B에 있는 C 법무사 사무실에서 권한 없이 위 법무사 사무실의 D 사무장에게 근저당권말소등기신청 관련 E 명의의 위임장을 작성하여 줄 것을 부탁하여 그로 하여금 컴퓨터를 이용하여 근저당권말소등기신청 위임장 양식에 "부동산의 표시 : 서울특별시 강남구 F건물 G동, 등기원인과 그 연월일 : 2014년 2월 12일 해지, 등기의 목적 : 근저당권 말소, 말소할 사항 : 2010년 11월 9일 접수 제68218호로 등기한 근저당권설정등기, 위임인 : 근저당권자 E, 경기도 고양시 덕양구 H건물 I호, 대리인 : A, 서울시 강남구 J건물 K호, 위 사람을 대리인으로 정하고 위 부동산 등기신청 및 취하에 관한 모든 행위를 위임한다."라고 입력하고 나서 출력한 후 E의 이름 옆에 미리 새겨 가지고 있던 E의 도장을 찍었다. 이로써 피고인은 행사할 목적으로 권리의무에 관한 사문서인 E 명의로 된 근저당권말소등기신청 위임장 1장을 위조하였다.\n2. 피고인은 2017. 8. 8.경 서울 서초구 서초동에 있는 서울중앙지방법원 등기국에서 위조된 사실을 알지 못하는 담당직원에게 근저당권말소등기신청을 하면서 위와 같이 위조한 근저당권말소등기신청 위임장 1장을 마치 진정하게 성립된 것처럼 제출하여 이를 행사하였다.', '피고인 2017. 12. 4. 16:31경 성남시 분당구 B에 있는 C 금은방에서 피해자 D의 남편 E에게 순금 20돈 목걸이를 판매하겠다고 거짓말하였다.\n그러나 사실 피고인은 피해자의 남편에게 판매한 금 목걸이 20돈은 18K 2돈과 금으로 도금한 가짜 목걸이 이었다.\n이로써 피고인은 피해자의 남편에게 18K 2돈짜리 목걸이면서도 순금 20돈의 금목걸이라고 속여 판매하고, 그 즉시 순금 20돈의 대금 3,488,000원 상당을 교부받아 이를 편취하였다.', '피고인은 2020. 12. 1. 09:57경 동두천시 동두천로 264에 있는 노인복지회관 엘리베이터 안에서 상의 점퍼 안주머니에 들어있던 위험한 물건인 부엌칼(전체 길이 약 30cm, 칼날길이 약 15cm)을 꺼내어 들고 있던 중 엘리베이터에 탑승하려다 이를 발견한 피해자 B(남, 68세)으로부터 "왜 칼을 들고 있냐"라는 말을 듣자 그 칼을 피해자를 향해 겨누며 "눈알을 파 버린다"라고 말하는 등 피해자에게 위해를 가할 것 같은 태도를 보여 피해자를 협박하였다.']

# %%
print(data_st_plus["train"]["statutes"][2])
print(data_st_plus["train"]["facts"][2])
# Out:
# ['전자금융거래법 제49조 제4항 제2호', '전자금융거래법 제6조 제3항 제3호', '형법 제30조', '형법 제347조 제1항']
# [전제사실] 전기통신사기 조직은 불특정 다수의 피해자들에게 사회관계망서비스 등을 이용하여 투자전문가 등을 사칭하며 가공의 투자상품 등에 관한 광고를 발송하는 등의 방법으로 피해자들을 기망하여 이에 속은 피해자들로 하여금 자신들이 관리하는 계좌로 금원을 이체 또는 무통장 입금받아 편취하는 조직으로, 범행 전체를 총괄하며 내부 각 점조직간의 유기적인 연락을 담당하는 ‘총책’, 총책의 지시를 받아 내부 조직원을 관리하며 그들에게 기망 수법과 현금수거 방법 등을 교육·지시하는 ‘관리책’, 투자전문가 등을 사칭하며 피해자들로 하여금 가공의 투자거래 웹사이트에 회원등록을 하고 투자금 명목으로 자금 이체하도록 유도하는 ‘기망책’, 계좌에 입금된 피해금을 인출하여 전달하거나 피해자들을 직접 만나 돈을 받아오는 ‘현금인출책·현금수거책’ 등으로 각각 분담된 역할을 수행하면서 검거에 대비하여 고도의 점조직 형태로 운영되고 있다. 1. 공모관계 피고인은 2021. 3. 중순경 C으로부터 전기통신사기 조직의 현금인출책으로 활동할 것을 제안받고 이를 수락하여, 자금세탁 용도로 설립된 이른바 ‘유령법인’ 명의의 계좌들 내지 피고인 본인 명의의 계좌들과 연결된 접근매체를 보관하면서, 위 각 계좌에 범죄피해금이 이체되면 이를 현금으로 인출하여 C 및 성명불상의 전기통신사기 조직원에게 전달하는 ‘현금인출책’ 역할을 담당하기로 하여 전기통신사기 범행을 하기로 순차 공모하였다. 2. 사기 가. 피해자 D에 대한 사기 성명불상의 전기통신사기 조직원은 2021. 3. 29.경 불상의 장소에서, 인터넷 웹사이트 ‘E(인터넷주소 1 생략)'에서 투자전문가를 사칭하며 피해자에게 1:1 주식 상담을 해주겠다고 접근한 다음, “실시간으로 진행되는 코인거래 체결량에 대한 결과 값을 추출, 분석, 비교해 수익을 내는 투자입니다. 선물옵션처럼 금지수 혹은 유가지수에 하는 투자와 마찬가지로 코인매수, 매도의 체결량에 따라 투자를 하는 방식입니다. 저희가 협력하고 있는 정보거래처는 국내 또는 중국에서 제일 큰 거래소이고, F, G, H 등 각 코인 거래소에서 체결수량을 매초 단위로 전송해주며, 저희는 분석프로그램과 저의 실력과 노하우를 통해, 확실할 때 고객님들의 투자 유치와 진행을 도와드리고 있습니다.”라는 취지로 거짓말하여 고수익을 올릴 수 있는 것처럼 말하면서 회원가입 및 투자를 유도하였다. 그러나 사실 위 성명불상자는 투자전문가가 아니었고, 피해자로부터 투자금 명목의 돈을 받더라도 이를 실제 투자에 사용할 의사나 능력이 없었다. 위 성명불상의 전기통신사기 조직원은 피해자를 위와 같이 기망하여 이에 속은 피해자로부터 2021. 3. 30.부터 2021. 4. 5.까지 별지 범죄일람표 1 기재와 같이 6회에 걸쳐 17,952,000원을 주식회사 I 명의의 J은행 계좌(계좌번호 1 생략) 및 주식회사 K 명의의 L 계좌(계좌번호 2 생략)로 이체받았다. 성명불상의 전기통신사기 조직원은 위와 같이 입금된 자금 중 2021. 3. 30.자 2만 원과 2021. 4. 2.자 400만 원을 M 주식회사 명의의 L은행 계좌(계좌번호 3 생략), N 명의의 우체국 계좌(계좌번호 4 생략), N 명의의 J은행 계좌(계좌번호 5 생략) O 명의의 P 계좌(계좌번호 6 생략), 주식회사 Q 명의의 R은행 계좌(계좌번호 7 생략)를 거쳐 피고인이 관련 접근매체를 관리하는 유한회사 S 명의의 L 계좌(계좌번호 8 생략), 유한회사 T 명의의 L 계좌(계좌번호 9 생략), 유한회사U 명의의 L 계좌(계좌번호 10 생략), 유한회사 V 명의의 L 계좌(계좌번호 11 생략), 피고인 명의의 L 계좌(계좌번호 12 생략), 피고인 명의의 W은행 계좌(계좌번호 13 생략) 등으로 이체하고, 피고인은 같은 날 위와 같이 이체된 자금을 현금으로 인출한 다음, 이를 C에게 전달하였다. 이로써 피고인은 C, 성명불상의 전기통신사기 조직원 등과 공모하여, 피해자를 기망하고 이에 속은 피해자로부터 17,952,000원을 편취하였다. 나. 피해자 B에 대한 사기 성명불상의 전기통신사기 조직원은 2021. 3. 26.경 불상의 장소에서, 인터넷 웹사이트 ‘E(인터넷주소 1 생략)'에서 투자전문가를 사칭하며 피해자에게 1:1 주식 상담을 해주겠다고 접근한 다음, “외환거래 투자 리딩을 도와주겠다. X과 미국 달러화를 사고파는 방식의 외환거래 중에 발생하는 환율 변동에 따른 차익을 얻는 형식의 투자종목에 투자하면, 원금의 300~500% 수익이 발생한다.”라는 취지로 거짓말하여 고수익을 올릴 수 있는 것처럼 말하면서 회원가입 및 투자를 유도하였다. 그러나 사실 위 성명불상자는 투자전문가가 아니었고, 피해자로부터 투자금 명목의 돈을 받더라도 이를 실제 투자에 사용할 의사나 능력이 없었다. 위 성명불상의 전기통신사기 조직원은 피해자를 위와 같이 기망하여 이에 속은 피해자로부터 2021. 3. 31.부터 2021. 4. 7.까지 별지 범죄일람표 2 기재와 같이 3회에 걸쳐 46,000,000원을 주식회사 I 명의의 J은행 계좌(계좌번호 1 생략) 및 주식회사 Y 명의의 L 계좌(계좌번호 14 생략)로 이체받았다. 성명불상의 전기통신사기 조직원은 위와 같이 입금된 자금 중 2021. 4. 2.자 1,100만 원과 2021. 4. 7.자 3,000만 원을 K 명의의 L 계좌(계좌번호 2 생략), M 주식회사 명의의 L계좌(계좌번호 3 생략), N 명의의 우체국 계좌(계좌번호 4 생략), N 명의의 J은행 계좌(계좌번호 5 생략) O 명의의 P 계좌(계좌번호 6 생략), 주식회사 Q 명의의 R은행 계좌(계좌번호 7 생략) 등을 거쳐 피고인이 관련 접근매체를 관리하는 유한회사 S 명의의 L 계좌(계좌번호 8 생략), 유한회사 T 명의의 L 계좌(계좌번호 9 생략), 유한회사 U 명의의 L 계좌(계좌번호 10 생략), 유한회사 V 명의의 L 계좌(계좌번호 11 생략), 피고인 명의의 L 계좌(계좌번호 12 생략), Z(C의 친동생) 명의의 AA은행 계좌(계좌번호 15 생략) 등으로 이체하고, 피고인은 2021. 4. 2.부터 2021. 4. 7.경까지 위와 같이 이체된 자금을 현금으로 인출한 다음 이를 C에게 전달하였다. 이로써 피고인은 C, 성명불상의 전기통신사기 조직원 등과 공모하여, 피해자를 기망하고 이에 속은 피해자로부터 46,000,000원을 편취하였다. 3. 전자금융거래법위반 전자금융거래 접근매체를 사용 및 관리함에 있어서 다른 법률에 특별한 규정이 없는 한 범죄에 이용할 목적으로 또는 범죄에 이용될 것을 알면서 접근매체를 보관하여서는 아니 된다. 그럼에도 피고인은 인터넷 투자사기 등 범죄에 이용할 목적으로 2021. 3. 20.경부터 2021. 4.말경까지 유한회사 S 명의 L 계좌(계좌번호 16 생략), 유한회사 T 명의의 L 계좌(계좌번호 9 생략), 유한회사 U 명의의 L 계좌(계좌번호 10 생략), 유한회사 V 명의의 L 계좌(계좌번호 11 생략)에 연결된 각 접근매체를, 2021. 3. 20.경부터 2021. 5. 26.까지 Z 명의의 AA은행 계좌(계좌번호 15 생략)에 연결된 접근매체를 각 보관하였다.
